# %% [markdown]
# # Plotting of Clarke and Wright Routing

# %% [markdown]
# This loads the EAM data for the Mykawa, Stafford, and Sweetwater (Houston (Canino) Hub) centers on the dates 5/17/18 and 5/24/18. The Clarke and Wright savings algorithm is applied to each dataset and the route generated is plotted. The Delauney triangulations and Voronoi Polygons for each day are also plotted.

# %%
import pandas as pd
from read_customers import get_df
from plotting import cw_plot, delaunay_plot
dist, my_517, my_524, staf_517, staf_524, swee_517, swee_524 = get_df()

# %% [markdown]
# This is the Delaunay triangulation of the customers serviced by the Mykawa facility on 5/17/18

# %%
delaunay_plot(my_517, dist)

# %% [markdown]
# This is the Delaunay triangulation of the customers serviced by the Mykawa facility on 5/24/18

# %%
delaunay_plot(my_524, dist)

# %% [markdown]
# This is the Delaunay triangulation of the customers serviced by the Stafford facility on 5/17/18

# %%
delaunay_plot(staf_517, dist)

# %% [markdown]
# This is the Delaunay triangulation of the customers serviced by the Stafford facility on 5/24/18

# %%
delaunay_plot(staf_524, dist)

# %% [markdown]
# This is the Delaunay triangulation of the customers serviced by the Houston (Canino) Hub facility on 5/17/18

# %%
delaunay_plot(swee_517, dist)

# %% [markdown]
# This is the Delaunay triangulation of the customers serviced by the Houston (Canino) Hub facility on 5/24/18

# %%
delaunay_plot(swee_524, dist)

# %% [markdown]
# This is the Clarke and Wright routing for the Mykawa facilities deliveries on 5/17/18.

# %%
cw_plot(my_517, dist)

# %% [markdown]
# This is the Clarke and Wright routing for the Mykawa facilities deliveries on 5/24/18

# %%
cw_plot(my_524, dist)
# Out:
# C:\Users\heast\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# This is the Clarke and Wright routing for the Stafford facilities' deliveries on 5/17/18.

# %%
cw_plot(staf_517, dist)

# %% [markdown]
# This is the Clarke and Wright routing for the Stafford facilities' deliveries on 5/24/18.

# %%
cw_plot(staf_524, dist)

# %% [markdown]
# This is the Clarke and Wright routing for the Houston (Canino) Hub facilities' deliveries on 5/17/18.

# %%
cw_plot(swee_517, dist)

# %% [markdown]
# This is the Clarke and Wright routing for the Houston (Canino) Hub facilities' deliveries on 5/24/18.

# %%
cw_plot(swee_524, dist)
